# %% [markdown]
# # VGG16 Retrain using custom layers

# %% [markdown]
# ### Imports

# %%
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, Convolution2D, MaxPooling2D, ZeroPadding2D
from keras import backend as k
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
import cv2, numpy as np
import matplotlib.pyplot as plt
import itertools
import os
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Setup Trainer

# %%
train_data_dir = "memes"
validation_data_dir = "memes_val"
test_data_dir = "memes_test"
nb_train_samples = 1313
nb_validation_samples = 454
batch_size = 16
epochs = 50

# %%
# plot images with labels
def plots(imgs, figsize=(12,6), rows=2, interp=False, titles=None):
    if type(imgs[0]) is np.ndarray:
        imgs = np.array(imgs).astype(np.uint8)
        if (imgs.shape[-1]!=3):
            imgs = imgs.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(imgs)//rows if len(imgs)%2 == 0 else len(imgs)//rows+1
    for i in range(len(imgs)):
        sp = f.add_subplot(rows,cols,i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=14)
        plt.imshow(imgs[i], interpolation=None if interp else 'none')

# %%
train_datagen = ImageDataGenerator(
#rescale = 1./255,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
#rotation_range=30
)

test_datagen = ImageDataGenerator(
#rescale = 1./255,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
#rotation_range=30
)

# %%
train_generator = ImageDataGenerator().flow_from_directory(
train_data_dir,
target_size=(224,224),
batch_size = batch_size,
class_mode = "categorical")

validation_generator = ImageDataGenerator().flow_from_directory(
validation_data_dir,
target_size=(224,224),
class_mode = "categorical")
# Out:
# Found 1313 images belonging to 18 classes.
# Found 454 images belonging to 18 classes.

# %% [markdown]
# ### Look at some Memes!

# %%
train_batches = ImageDataGenerator().flow_from_directory(train_data_dir, target_size=(224,224), batch_size=4)
# Out:
# Found 1313 images belonging to 18 classes.

# %%
for (dirpath, dirnames, filenames) in os.walk('memes'):
    print(dirnames)
    meme_labels = dirnames
    break
# Out:
# ['Art Classical', 'Blacman Feels', 'Cartoons', 'Comics Original', 'Cool Stuff IRL', 'Doggo n Kitty', 'Drake', 'Escalating', 'FBI SMS', 'Forums', 'Modern Whos Whens', 'Stills Movies', 'Stock', 'Texts', 'Twitter FB Forums', 'Versus', 'Web is Crazy', 'World']

# %%
imgs, labels = next(train_batches)
c = []
for l in labels:
    for i in range(len(l)):
        if l[i]>0:
            c.append(meme_labels[i])
plots(imgs, titles=c)

# %% [markdown]
# ### Build VGG16 Model

# %%
vgg_model = applications.vgg16.VGG16(weights = "vgg16_weights_tf_dim_ordering_tf_kernels.h5", include_top=True)
print('getting VGG16 model')
print(type(vgg_model))
model = Sequential()
for layer in vgg_model.layers[:-1]:
    model.add(layer)
model.summary()
print(type(model))
# Out:
# getting VGG16 model
# <class 'keras.engine.training.Model'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________
# <class 'keras.engine.sequential.Sequential'>

# %%
for layer in model.layers:
    layer.trainable = False
print('freezing all layers')
model.add(Dense(18, activation="softmax"))
model.summary()
# Out:
# freezing all layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 18)                73746
# =================================================================
# Total params: 134,334,290
# Trainable params: 73,746
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
model.compile(optimizers.Adam(lr=0.0001), loss = 'categorical_crossentropy',metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint("vgg16_new.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=10, verbose=1, mode='auto')

# %%
model.fit_generator(
train_generator,
steps_per_epoch = nb_train_samples//batch_size,
epochs = epochs,
validation_data = validation_generator,
validation_steps = nb_validation_samples//batch_size,
callbacks = [checkpoint, early])
# Out:
# Epoch 1/50
# 82/82 [==============================] - 40s 485ms/step - loss: 2.5540 - acc: 0.2005 - val_loss: 2.5687 - val_acc: 0.1908
#
# Epoch 00001: val_acc improved from -inf to 0.19080, saving model to vgg16_new.h5
# Epoch 2/50
# 82/82 [==============================] - 29s 355ms/step - loss: 2.3670 - acc: 0.2645 - val_loss: 2.4348 - val_acc: 0.2630
#
# Epoch 00002: val_acc improved from 0.19080 to 0.26303, saving model to vgg16_new.h5
# Epoch 3/50
# 82/82 [==============================] - 29s 350ms/step - loss: 2.2432 - acc: 0.3080 - val_loss: 2.3314 - val_acc: 0.2642
#
# Epoch 00003: val_acc improved from 0.26303 to 0.26422, saving model to vgg16_new.h5
# Epoch 4/50
# 82/82 [==============================] - 28s 347ms/step - loss: 2.1634 - acc: 0.3316 - val_loss: 2.2234 - val_acc: 0.3057
#
# Epoch 00004: val_acc improved from 0.26422 to 0.30569, saving model to vgg16_new.h5
# Epoch 5/50
# 82/82 [==============================] - 29s 352ms/step - loss: 2.0925 - acc: 0.3430 - val_loss: 2.1902 - val_acc: 0.3223
#
# Epoch 00005: val_acc improved from 0.30569 to 0.32227, saving model to vgg16_new.h5
# Epoch 6/50
# 82/82 [==============================] - 29s 350ms/step - loss: 2.0603 - acc: 0.3690 - val_loss: 2.1371 - val_acc: 0.3815
#
# Epoch 00006: val_acc improved from 0.32227 to 0.38152, saving model to vgg16_new.h5
# Epoch 7/50
# 82/82 [==============================] - 28s 347ms/step - loss: 1.9752 - acc: 0.3856 - val_loss: 2.1055 - val_acc: 0.3116
#
# Epoch 00007: val_acc did not improve from 0.38152
# Epoch 8/50
# 82/82 [==============================] - 29s 348ms/step - loss: 1.9756 - acc: 0.3834 - val_loss: 2.0675 - val_acc: 0.3839
#
# Epoch 00008: val_acc improved from 0.38152 to 0.38391, saving model to vgg16_new.h5
# Epoch 9/50
# 82/82 [==============================] - 29s 352ms/step - loss: 1.9299 - acc: 0.4147 - val_loss: 2.0426 - val_acc: 0.3768
#
# Epoch 00009: val_acc did not improve from 0.38391
# Epoch 10/50
# 82/82 [==============================] - 29s 351ms/step - loss: 1.8810 - acc: 0.4252 - val_loss: 1.9933 - val_acc: 0.3851
#
# Epoch 00010: val_acc improved from 0.38391 to 0.38507, saving model to vgg16_new.h5
# Epoch 11/50
# 82/82 [==============================] - 29s 353ms/step - loss: 1.8538 - acc: 0.4382 - val_loss: 1.9669 - val_acc: 0.3981
#
# Epoch 00011: val_acc improved from 0.38507 to 0.39810, saving model to vgg16_new.h5
# Epoch 12/50
# 82/82 [==============================] - 29s 355ms/step - loss: 1.8245 - acc: 0.4252 - val_loss: 1.9998 - val_acc: 0.3685
#
# Epoch 00012: val_acc did not improve from 0.39810
# Epoch 13/50
# 82/82 [==============================] - 28s 338ms/step - loss: 1.7930 - acc: 0.4473 - val_loss: 2.0406 - val_acc: 0.3555
#
# Epoch 00013: val_acc did not improve from 0.39810
# Epoch 14/50
# 82/82 [==============================] - 29s 348ms/step - loss: 1.7940 - acc: 0.4534 - val_loss: 1.9167 - val_acc: 0.4123
#
# Epoch 00014: val_acc improved from 0.39810 to 0.41232, saving model to vgg16_new.h5
# Epoch 15/50
# 82/82 [==============================] - 28s 343ms/step - loss: 1.7667 - acc: 0.4649 - val_loss: 1.9402 - val_acc: 0.3874
#
# Epoch 00015: val_acc did not improve from 0.41232
# Epoch 16/50
# 82/82 [==============================] - 28s 344ms/step - loss: 1.7540 - acc: 0.4580 - val_loss: 1.9180 - val_acc: 0.4046
#
# Epoch 00016: val_acc did not improve from 0.41232
# Epoch 17/50
# 82/82 [==============================] - 29s 348ms/step - loss: 1.7166 - acc: 0.4642 - val_loss: 1.9000 - val_acc: 0.4088
#
# Epoch 00017: val_acc did not improve from 0.41232
# Epoch 18/50
# 82/82 [==============================] - 29s 349ms/step - loss: 1.7282 - acc: 0.4755 - val_loss: 1.8904 - val_acc: 0.4159
#
# Epoch 00018: val_acc improved from 0.41232 to 0.41588, saving model to vgg16_new.h5
# Epoch 19/50
# 82/82 [==============================] - 29s 351ms/step - loss: 1.6721 - acc: 0.4696 - val_loss: 1.8861 - val_acc: 0.4100
#
# Epoch 00019: val_acc did not improve from 0.41588
# Epoch 20/50
# 82/82 [==============================] - 29s 352ms/step - loss: 1.6614 - acc: 0.4854 - val_loss: 1.9035 - val_acc: 0.3981
#
# Epoch 00020: val_acc did not improve from 0.41588
# Epoch 21/50
# 82/82 [==============================] - 28s 342ms/step - loss: 1.6585 - acc: 0.4763 - val_loss: 1.8443 - val_acc: 0.4194
#
# Epoch 00021: val_acc improved from 0.41588 to 0.41943, saving model to vgg16_new.h5
# Epoch 22/50
# 82/82 [==============================] - 28s 339ms/step - loss: 1.6522 - acc: 0.4825 - val_loss: 1.9117 - val_acc: 0.3910
#
# Epoch 00022: val_acc did not improve from 0.41943
# Epoch 23/50
# 82/82 [==============================] - 28s 342ms/step - loss: 1.6413 - acc: 0.4749 - val_loss: 1.8509 - val_acc: 0.4207
#
# Epoch 00023: val_acc improved from 0.41943 to 0.42069, saving model to vgg16_new.h5
# Epoch 24/50
# 82/82 [==============================] - 28s 346ms/step - loss: 1.6709 - acc: 0.4856 - val_loss: 1.8778 - val_acc: 0.4040
#
# Epoch 00024: val_acc did not improve from 0.42069
# Epoch 25/50
# 82/82 [==============================] - 28s 343ms/step - loss: 1.5777 - acc: 0.5115 - val_loss: 1.8019 - val_acc: 0.4277
#
# Epoch 00025: val_acc improved from 0.42069 to 0.42773, saving model to vgg16_new.h5
# Epoch 26/50
# 82/82 [==============================] - 28s 339ms/step - loss: 1.6038 - acc: 0.4894 - val_loss: 1.7708 - val_acc: 0.4289
#
# Epoch 00026: val_acc improved from 0.42773 to 0.42891, saving model to vgg16_new.h5
# Epoch 27/50
# 82/82 [==============================] - 29s 349ms/step - loss: 1.5884 - acc: 0.5182 - val_loss: 1.8004 - val_acc: 0.4147
#
# Epoch 00027: val_acc did not improve from 0.42891
# Epoch 28/50
# 82/82 [==============================] - 29s 353ms/step - loss: 1.6154 - acc: 0.5016 - val_loss: 1.8446 - val_acc: 0.4277
#
# Epoch 00028: val_acc did not improve from 0.42891
# Epoch 29/50
# 82/82 [==============================] - 28s 347ms/step - loss: 1.5456 - acc: 0.5243 - val_loss: 1.8406 - val_acc: 0.4254
#
# Epoch 00029: val_acc did not improve from 0.42891
# Epoch 30/50
# 82/82 [==============================] - 28s 340ms/step - loss: 1.5756 - acc: 0.5168 - val_loss: 1.8055 - val_acc: 0.4408
#
# Epoch 00030: val_acc improved from 0.42891 to 0.44076, saving model to vgg16_new.h5
# Epoch 31/50
# 82/82 [==============================] - 28s 346ms/step - loss: 1.5453 - acc: 0.5228 - val_loss: 1.7629 - val_acc: 0.4448
#
# Epoch 00031: val_acc improved from 0.44076 to 0.44483, saving model to vgg16_new.h5
# Epoch 32/50
# 82/82 [==============================] - 28s 343ms/step - loss: 1.5760 - acc: 0.5054 - val_loss: 1.8154 - val_acc: 0.4277
#
# Epoch 00032: val_acc did not improve from 0.44483
# Epoch 33/50
# 82/82 [==============================] - 29s 350ms/step - loss: 1.5497 - acc: 0.5380 - val_loss: 1.8080 - val_acc: 0.4372
#
# Epoch 00033: val_acc did not improve from 0.44483
# Epoch 34/50
# 82/82 [==============================] - 28s 346ms/step - loss: 1.5578 - acc: 0.5380 - val_loss: 1.7495 - val_acc: 0.4372
#
# Epoch 00034: val_acc did not improve from 0.44483
# Epoch 35/50
# 82/82 [==============================] - 29s 352ms/step - loss: 1.5555 - acc: 0.5092 - val_loss: 1.7594 - val_acc: 0.4455
#
# Epoch 00035: val_acc improved from 0.44483 to 0.44550, saving model to vgg16_new.h5
# Epoch 36/50
# 82/82 [==============================] - 28s 343ms/step - loss: 1.5008 - acc: 0.5411 - val_loss: 1.8061 - val_acc: 0.4052
#
# Epoch 00036: val_acc did not improve from 0.44550
# Epoch 37/50
# 82/82 [==============================] - 28s 345ms/step - loss: 1.5550 - acc: 0.5184 - val_loss: 1.7436 - val_acc: 0.4704
#
# Epoch 00037: val_acc improved from 0.44550 to 0.47038, saving model to vgg16_new.h5
# Epoch 38/50
# 82/82 [==============================] - 29s 353ms/step - loss: 1.5213 - acc: 0.5327 - val_loss: 1.7557 - val_acc: 0.4149
#
# Epoch 00038: val_acc did not improve from 0.47038
# Epoch 39/50
# 82/82 [==============================] - 28s 346ms/step - loss: 1.4733 - acc: 0.5449 - val_loss: 1.7375 - val_acc: 0.4514
#
# Epoch 00039: val_acc did not improve from 0.47038
# Epoch 40/50
# 82/82 [==============================] - 29s 351ms/step - loss: 1.5131 - acc: 0.5245 - val_loss: 1.7505 - val_acc: 0.4526
#
# Epoch 00040: val_acc did not improve from 0.47038
# Epoch 41/50
# 82/82 [==============================] - 27s 332ms/step - loss: 1.4857 - acc: 0.5533 - val_loss: 1.7579 - val_acc: 0.4265
#
# Epoch 00041: val_acc did not improve from 0.47038
# Epoch 42/50
# 82/82 [==============================] - 29s 354ms/step - loss: 1.5225 - acc: 0.5268 - val_loss: 1.7406 - val_acc: 0.4562
#
# Epoch 00042: val_acc did not improve from 0.47038
# Epoch 43/50
# 82/82 [==============================] - 29s 358ms/step - loss: 1.4748 - acc: 0.5403 - val_loss: 1.7671 - val_acc: 0.4585
#
# Epoch 00043: val_acc did not improve from 0.47038
# Epoch 44/50
# 82/82 [==============================] - 29s 348ms/step - loss: 1.4420 - acc: 0.5351 - val_loss: 1.7348 - val_acc: 0.4443
#
# Epoch 00044: val_acc did not improve from 0.47038
# Epoch 45/50
# 82/82 [==============================] - 28s 336ms/step - loss: 1.4542 - acc: 0.5480 - val_loss: 1.7847 - val_acc: 0.4289
#
# Epoch 00045: val_acc did not improve from 0.47038
# Epoch 46/50
# 82/82 [==============================] - 29s 350ms/step - loss: 1.4693 - acc: 0.5374 - val_loss: 1.7512 - val_acc: 0.4287
#
# Epoch 00046: val_acc did not improve from 0.47038
# Epoch 47/50
# 82/82 [==============================] - 29s 352ms/step - loss: 1.4494 - acc: 0.5473 - val_loss: 1.6949 - val_acc: 0.4479
#
# Epoch 00047: val_acc did not improve from 0.47038
# Epoch 00047: early stopping

# %%
test_batches = ImageDataGenerator().flow_from_directory(test_data_dir, target_size=(224,224), batch_size=4)
# Out:
# Found 454 images belonging to 18 classes.

# %%
imgs, labels = next(test_batches)
c = []
for l in labels:
    for i in range(len(l)):
        if l[i]>0:
            c.append(meme_labels[i])
plots(imgs, titles=c)

# %%
pred = model.predict_generator(test_batches, steps=4, verbose=1)
pred = np.round(pred)
d = []
for l in pred:
    for i in range(len(l)):
        if l[i]>0:
            d.append(meme_labels[i])
d
# Out:
# 4/4 [==============================] - 0s 75ms/step
# ['Twitter FB Forums',
#  'Forums',
#  'World',
#  'Modern Whos Whens',
#  'Forums',
#  'Comics Original',
#  'Cool Stuff IRL',
#  'Twitter FB Forums',
#  'Modern Whos Whens',
#  'Cartoons',
#  'Versus',
#  'Comics Original',
#  'World',
#  'Comics Original',
#  'World',
#  'Versus']
