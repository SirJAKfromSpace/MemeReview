# %% [markdown]
# # VGG16 Retrain using custom layers

# %% [markdown]
# ### Imports

# %%
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, Convolution2D, MaxPooling2D, ZeroPadding2D
from keras import backend as k
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
import cv2, numpy as np
import matplotlib.pyplot as plt
import itertools
import os
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Setup Trainer

# %%
train_data_dir = "m_trn"
validation_data_dir = "m_val"
test_data_dir = "memes_test"
nb_train_samples = 848 #1313
nb_validation_samples = 313 #454
batch_size = 20
epochs = 50

# %%
# plot images with labels
def plots(imgs, figsize=(12,6), rows=2, interp=False, titles=None):
    if type(imgs[0]) is np.ndarray:
        imgs = np.array(imgs).astype(np.uint8)
        if (imgs.shape[-1]!=3):
            imgs = imgs.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(imgs)//rows if len(imgs)%2 == 0 else len(imgs)//rows+1
    for i in range(len(imgs)):
        sp = f.add_subplot(rows,cols,i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=14)
        plt.imshow(imgs[i], interpolation=None if interp else 'none')

# %%
train_datagen = ImageDataGenerator(
#rescale = 1./255,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
#rotation_range=30
)

test_datagen = ImageDataGenerator(
#rescale = 1./255,
fill_mode = "nearest",
zoom_range = 0.2,
width_shift_range = 0.2,
height_shift_range=0.2,
#rotation_range=30
)

# %%
train_generator = ImageDataGenerator().flow_from_directory(
train_data_dir,
target_size=(224,224),
batch_size = batch_size,
class_mode = "categorical")

validation_generator = ImageDataGenerator().flow_from_directory(
validation_data_dir,
target_size=(224,224),
class_mode = "categorical")
# Out:
# Found 848 images belonging to 10 classes.
# Found 271 images belonging to 10 classes.

# %% [markdown]
# ### Look at some Memes!

# %%
train_batches = ImageDataGenerator().flow_from_directory(train_data_dir, target_size=(224,224), batch_size=4)
# Out:
# Found 848 images belonging to 10 classes.

# %%
for (dirpath, dirnames, filenames) in os.walk('m_trn'):
    print(dirnames)
    meme_labels = dirnames
    break
# Out:
# ['Art Classical', 'Cartoons', 'Comics Original', 'Doggo n Kitty', 'Drake', 'Escalating', 'Stock', 'Texts', 'Twitter FB Forums', 'World']

# %%
imgs, labels = next(train_batches)
c = []
for l in labels:
    for i in range(len(l)):
        if l[i]>0:
            c.append(meme_labels[i])
plots(imgs, titles=c)

# %% [markdown]
# ### Build VGG16 Model

# %%
vgg_model = applications.vgg16.VGG16(weights = "vgg16_weights_tf_dim_ordering_tf_kernels.h5", include_top=True)
print('getting VGG16 model')
print(type(vgg_model))
model = Sequential()
for layer in vgg_model.layers[:-1]:
    model.add(layer)
model.summary()
print(type(model))
# Out:
# getting VGG16 model
# <class 'keras.engine.training.Model'>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________
# <class 'keras.engine.sequential.Sequential'>

# %%
for layer in model.layers:
    layer.trainable = False
print('freezing all layers')
model.add(Dense(10, activation="softmax", name='prediction'))
model.summary()
# Out:
# freezing all layers
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# prediction (Dense)           (None, 10)                40970
# =================================================================
# Total params: 134,301,514
# Trainable params: 40,970
# Non-trainable params: 134,260,544
# _________________________________________________________________

# %%
model.compile(optimizers.Adam(lr=0.0001), loss = 'categorical_crossentropy',metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint("vgg16_new_small.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=10, verbose=1, mode='auto')

# %%
model.fit_generator(
train_generator,
steps_per_epoch = nb_train_samples//batch_size,
epochs = epochs,
validation_data = validation_generator,
validation_steps = nb_validation_samples//batch_size,
callbacks = [checkpoint, early])
# Out:
# Epoch 1/50
# 42/42 [==============================] - 18s 420ms/step - loss: 2.4980 - acc: 0.2655 - val_loss: 2.1577 - val_acc: 0.3866
#
# Epoch 00001: val_acc improved from -inf to 0.38661, saving model to vgg16_new_small.h5
# Epoch 2/50
# 42/42 [==============================] - 14s 337ms/step - loss: 1.4847 - acc: 0.5125 - val_loss: 1.6270 - val_acc: 0.5045
#
# Epoch 00002: val_acc improved from 0.38661 to 0.50448, saving model to vgg16_new_small.h5
# Epoch 3/50
# 42/42 [==============================] - 14s 338ms/step - loss: 1.0975 - acc: 0.6399 - val_loss: 1.3478 - val_acc: 0.5919
#
# Epoch 00003: val_acc improved from 0.50448 to 0.59193, saving model to vgg16_new_small.h5
# Epoch 4/50
# 42/42 [==============================] - 14s 341ms/step - loss: 0.8692 - acc: 0.7184 - val_loss: 1.2308 - val_acc: 0.6156
#
# Epoch 00004: val_acc improved from 0.59193 to 0.61555, saving model to vgg16_new_small.h5
# Epoch 5/50
# 42/42 [==============================] - 14s 337ms/step - loss: 0.7817 - acc: 0.7465 - val_loss: 1.1430 - val_acc: 0.6682
#
# Epoch 00005: val_acc improved from 0.61555 to 0.66816, saving model to vgg16_new_small.h5
# Epoch 6/50
# 42/42 [==============================] - 14s 338ms/step - loss: 0.6617 - acc: 0.7893 - val_loss: 1.1733 - val_acc: 0.6637
#
# Epoch 00006: val_acc did not improve from 0.66816
# Epoch 7/50
# 42/42 [==============================] - 14s 341ms/step - loss: 0.5687 - acc: 0.8030 - val_loss: 1.0606 - val_acc: 0.6911
#
# Epoch 00007: val_acc improved from 0.66816 to 0.69114, saving model to vgg16_new_small.h5
# Epoch 8/50
# 42/42 [==============================] - 14s 338ms/step - loss: 0.5455 - acc: 0.8286 - val_loss: 1.1493 - val_acc: 0.6816
#
# Epoch 00008: val_acc did not improve from 0.69114
# Epoch 9/50
# 42/42 [==============================] - 14s 337ms/step - loss: 0.4484 - acc: 0.8690 - val_loss: 1.1020 - val_acc: 0.6883
#
# Epoch 00009: val_acc did not improve from 0.69114
# Epoch 10/50
# 42/42 [==============================] - 14s 343ms/step - loss: 0.4431 - acc: 0.8785 - val_loss: 1.1233 - val_acc: 0.6803
#
# Epoch 00010: val_acc did not improve from 0.69114
# Epoch 11/50
# 42/42 [==============================] - 14s 340ms/step - loss: 0.3746 - acc: 0.8964 - val_loss: 1.0725 - val_acc: 0.6973
#
# Epoch 00011: val_acc improved from 0.69114 to 0.69731, saving model to vgg16_new_small.h5
# Epoch 12/50
# 42/42 [==============================] - 14s 338ms/step - loss: 0.3476 - acc: 0.9154 - val_loss: 1.0504 - val_acc: 0.6951
#
# Epoch 00012: val_acc did not improve from 0.69731
# Epoch 13/50
# 42/42 [==============================] - 14s 342ms/step - loss: 0.3475 - acc: 0.9077 - val_loss: 1.0341 - val_acc: 0.7019
#
# Epoch 00013: val_acc improved from 0.69731 to 0.70194, saving model to vgg16_new_small.h5
# Epoch 14/50
# 42/42 [==============================] - 14s 338ms/step - loss: 0.3125 - acc: 0.9238 - val_loss: 1.1265 - val_acc: 0.6682
#
# Epoch 00014: val_acc did not improve from 0.70194
# Epoch 15/50
# 42/42 [==============================] - 14s 339ms/step - loss: 0.2792 - acc: 0.9304 - val_loss: 1.0389 - val_acc: 0.7063
#
# Epoch 00015: val_acc improved from 0.70194 to 0.70628, saving model to vgg16_new_small.h5
# Epoch 16/50
# 42/42 [==============================] - 15s 346ms/step - loss: 0.2720 - acc: 0.9339 - val_loss: 1.1232 - val_acc: 0.6890
#
# Epoch 00016: val_acc did not improve from 0.70628
# Epoch 17/50
# 42/42 [==============================] - 14s 343ms/step - loss: 0.2371 - acc: 0.9488 - val_loss: 1.0174 - val_acc: 0.6973
#
# Epoch 00017: val_acc did not improve from 0.70628
# Epoch 18/50
# 42/42 [==============================] - 14s 340ms/step - loss: 0.2356 - acc: 0.9488 - val_loss: 1.1051 - val_acc: 0.6973
#
# Epoch 00018: val_acc did not improve from 0.70628
# Epoch 19/50
# 42/42 [==============================] - 14s 343ms/step - loss: 0.2101 - acc: 0.9554 - val_loss: 1.0573 - val_acc: 0.7063
#
# Epoch 00019: val_acc did not improve from 0.70628
# Epoch 20/50
# 42/42 [==============================] - 14s 341ms/step - loss: 0.2135 - acc: 0.9583 - val_loss: 1.0912 - val_acc: 0.6883
#
# Epoch 00020: val_acc did not improve from 0.70628
# Epoch 21/50
# 42/42 [==============================] - 14s 339ms/step - loss: 0.1817 - acc: 0.9655 - val_loss: 1.0837 - val_acc: 0.6906
#
# Epoch 00021: val_acc did not improve from 0.70628
# Epoch 22/50
# 42/42 [==============================] - 14s 342ms/step - loss: 0.1932 - acc: 0.9607 - val_loss: 1.0804 - val_acc: 0.6868
#
# Epoch 00022: val_acc did not improve from 0.70628
# Epoch 23/50
# 42/42 [==============================] - 14s 339ms/step - loss: 0.1570 - acc: 0.9774 - val_loss: 1.0911 - val_acc: 0.6996
#
# Epoch 00023: val_acc did not improve from 0.70628
# Epoch 24/50
# 42/42 [==============================] - 14s 339ms/step - loss: 0.1579 - acc: 0.9690 - val_loss: 1.0687 - val_acc: 0.6951
#
# Epoch 00024: val_acc did not improve from 0.70628
# Epoch 25/50
# 42/42 [==============================] - 14s 343ms/step - loss: 0.1590 - acc: 0.9786 - val_loss: 1.0973 - val_acc: 0.6955
#
# Epoch 00025: val_acc did not improve from 0.70628
# Epoch 00025: early stopping

# %%
test_batches = ImageDataGenerator().flow_from_directory(test_data_dir, target_size=(224,224), batch_size=4)
# Out:
# Found 454 images belonging to 18 classes.

# %%
imgs, labels = next(test_batches)
c = []
for l in labels:
    for i in range(len(l)):
        if l[i]>0:
            c.append(meme_labels[i])
plots(imgs, titles=c)

# %%
pred = model.predict_generator(test_batches, steps=4, verbose=1)
pred = np.round(pred)
d = []
for l in pred:
    for i in range(len(l)):
        if l[i]>0:
            d.append(meme_labels[i])
d
# Out:
# 4/4 [==============================] - 0s 75ms/step
# ['Twitter FB Forums',
#  'Forums',
#  'World',
#  'Modern Whos Whens',
#  'Forums',
#  'Comics Original',
#  'Cool Stuff IRL',
#  'Twitter FB Forums',
#  'Modern Whos Whens',
#  'Cartoons',
#  'Versus',
#  'Comics Original',
#  'World',
#  'Comics Original',
#  'World',
#  'Versus']
